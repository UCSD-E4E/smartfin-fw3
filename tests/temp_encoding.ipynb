# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
real_temp = np.linspace(-10,40,200, dtype=np.float32)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(real_temp, (128.0 * (real_temp)).astype(np.int16), label='Dry')
ax.plot(real_temp, (128.0 * (real_temp - 100)).astype(np.int16), label='Wet')
ax.grid()
fig.legend()
fig.show()
# Out:
# C:\Users\nthui\AppData\Local\Temp\ipykernel_28952\671378748.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
